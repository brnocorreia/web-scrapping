# %%
import requests
from bs4 import BeautifulSoup
import re
import pandas as pd
import numpy as np

# %%
# Vamos procurar as 50 primeiras empresas. Como cada página tem 10 empresas, buscaremos as 5 primeiras páginas. #

complete_list = []

for i in range(1,6):

    # Setando os parâmetros de url e headers para acesso a página #
    url_match = f'https://www.glassdoor.com.br/Avalia%C3%A7%C3%B5es/index.htm?overall_rating_low=0&page={i}&filterType=RATING_OVERALL'
    headers = {'user-agent':'Mozilla/5.0'}

    # Realizando o get do código macarrônico em HTML da página #
    response = requests.get(url_match, headers = headers)

    # Transformando o código macarrônico em algo mais estruturado, processo de 'parser' #
    soup = response.text
    beautiful_soup = BeautifulSoup(soup, 'html.parser')

    # Buscando todos os nomes, avaliações e segmentos e pondo-os em uma lista a ser limpa posteriormente #
    employer_name_list = beautiful_soup.find_all('h2', {'data-test': re.compile('employer-short-name')})
    employer_rating_list = beautiful_soup.find_all('span', {'data-test': re.compile('rating')})
    employer_industry_list = beautiful_soup.find_all('span', {'data-test': re.compile('employer-industry')})
    

    for name, rating, industry in zip(employer_name_list, employer_rating_list, employer_industry_list):
        employer_name = name.text
        employer_rating = rating.text.replace(',','.')
        employer_industry = industry.text

        complete_list.append((employer_industry, employer_name, employer_rating))

        
df_complete = pd.DataFrame(complete_list, columns = ['Segmento','Nome', 'Avaliação (0.0 - 5.0)'])
df_complete
# Out:
#                                         Segmento  \
# 0                        Consultoria empresarial
# 1   Serviços de apoio à tecnologia da informação
# 2               Contabilidade e serviços fiscais
# 3                Serviços bancários e de crédito
# 4                           Restaurantes e cafés
# 5                        Internet e serviços Web
# 6      Soluções de software e redes corporativas
# 7               Contabilidade e serviços fiscais
# 8               Contabilidade e serviços fiscais
# 9                   Serviços de telecomunicações
# 10                       Consultoria empresarial
# 11                   Desenvolvimento de hardware
# 12                Hipermercados e lojas em geral
# 13               Serviços bancários e de crédito
# 14               Serviços bancários e de crédito
# 15  Serviços de apoio à tecnologia da informação
# 16                       Internet e serviços Web
# 17                  Serviços de telecomunicações
# 18                             Consultoria de RH
# 19  Serviços de apoio à tecnologia da informação
# 20               Produção de alimentos e bebidas
# 21  Serviços de apoio à tecnologia da informação
# 22                       Outras lojas varejistas
# 23  Serviços de apoio à tecnologia da informação
# 24     Soluções de software e redes corporativas
# 25                   Desenvolvimento de hardware
# 26     Soluções de software e redes corporativas
# 27               Produção de alimentos e bebidas
# 28                Hipermercados e lojas em geral
# 29                   Produção de bens de consumo
# 30  Serviços de apoio à tecnologia da informação
# 31               Produção de alimentos e bebidas
# 32                        Fabricação de máquinas
# 33                   Desenvolvimento de hardware
# 34                 Serviços de saúde e hospitais
# 35                  Biotecnologia e farmacêutica
# 36            Fabricação de produtos eletrônicos
# 37                   Produção de bens de consumo
# 38                          Restaurantes e cafés
# 39  Serviços de apoio à tecnologia da informação
# 40                 Serviços de saúde e hospitais
# 41               Serviços bancários e de crédito
# 42        Produção de equipamentos de transporte
# 43                          Mineração e extração
# 44       Processamento de transações financeiras
# 45                                           N/A
# 46               Serviços bancários e de crédito
# 47                          Restaurantes e cafés
# 48        Produção de equipamentos de transporte
# 49                             Consultoria de RH
#
#                                Nome Avaliação (0.0 - 5.0)
# 0                         Accenture                   4.2
# 1                               IBM                   4.4
# 2                          Deloitte                   4.0
# 3   Itaú Unibanco (Itaú BBA e Rede)                   4.5
# 4                        McDonald's                   3.5
# 5                            Amazon                   4.5
# 6                         Capgemini                   4.0
# 7                                EY                   3.9
# 8                               PwC                   4.0
# 9                   Teleperformance                   3.9
# 10                             KPMG                   3.8
# 11        Tata Consultancy Services                   3.9
# 12                          Walmart                   3.3
# 13                        Santander                   3.9
# 14                   Banco Bradesco                   4.2
# 15                       Concentrix                   4.1
# 16                           Google                   4.4
# 17         Vivo (Telefônica Brasil)                   4.5
# 18                           Atento                   3.6
# 19   Cognizant Technology Solutions                   3.8
# 20                            Ambev                   4.2
# 21                Dell Technologies                   4.3
# 22                  americanas s.a.                   4.1
# 23                            Wipro                   3.8
# 24                           Oracle                   4.4
# 25                        Microsoft                   4.4
# 26                              SAP                   4.4
# 27                           Nestlé                   4.1
# 28                        Carrefour                   3.7
# 29                         Unilever                   4.3
# 30                          Infosys                   3.9
# 31                          PepsiCo                   4.3
# 32                               GE                   4.0
# 33                     Robert Bosch                   4.4
# 34               UnitedHealth Group                   3.9
# 35                Johnson & Johnson                   4.2
# 36                          Siemens                   4.1
# 37                 Procter & Gamble                   4.2
# 38                      Burger King                   3.4
# 39                        Stefanini                   3.8
# 40                           Unimed                   4.2
# 41                             HSBC                   3.8
# 42              General Motors (GM)                   4.0
# 43                             Vale                   4.3
# 44                            Stone                   4.1
# 45                    Raia Drogasil                   3.7
# 46                  Banco do Brasil                   4.3
# 47                        Starbucks                   3.7
# 48               Ford Motor Company                   4.1
# 49                       Freelancer                   4.2
